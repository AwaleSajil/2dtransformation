# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

points = np.random.randint(low = -15, high= 15, size= (3, 2))
points = np.vstack((points, points[0]))

scale = np.diag([3,3])
pivot = np.array([0,0])

shiftpoints = points - pivot
newpoints = np.dot(shiftpoints, scale)

print("points", points)
print("shiftpoints", shiftpoints)
print("newpoints", newpoints)
# Out:
# points [[ 12   7]
#  [-15 -11]
#  [ -6   0]
#  [ 12   7]]
# shiftpoints [[ 12   7]
#  [-15 -11]
#  [ -6   0]
#  [ 12   7]]
# newpoints [[ 36  21]
#  [-45 -33]
#  [-18   0]
#  [ 36  21]]

# %%
plt.plot(points[:,0], points[:,1])
plt.plot(newpoints[:,0], newpoints[:,1])
